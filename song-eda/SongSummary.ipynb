# %%
from sqlalchemy import create_engine
import pandas as pd

# %%
engine = create_engine('postgresql+psycopg2://musiq:musiq@localhost:4444/musiq')

# %%
wrap = lambda c: ", ".join(k.strip() for k in c.strip().split("\n") if k.strip() not in ("", None))

# %%
def song_listing(conn):
    songs = []
    rs = conn.execute('select * from song')
    for row in rs:
        songs.append({
            'id': row[0],
            'track_id': row[1],
            'artist': row[2].lower(),
            'name': row[3],
            'cover_image': row[4],
            'link': row[5],
            'lyric': wrap(row[6]) if row[6] else None,
            'language': row[7],
        })
        
    return songs

# %%
def siamzone_listing(conn):
    siamzone = []
    rs = conn.execute('select * from siamzone_song')
    
    for row in rs:
        siamzone.append({
            'id': row[0],
            'song_id': row[1],
            'artist': row[2].lower(),
            'artist_en': row[3].lower() if row[3] else None,
            'name': row[4].lower(),
            'lyric': wrap(row[5]) if row[5] else None,
        })
        
    return siamzone

# %%
def artist_mapping_listing(conn):
    artist_map = []
    rs = conn.execute('select * from artist_map')
    for row in rs:
        artist_map.append({
            'id': row[0],
            'artist': row[1],
            'siamzone_artist': row[2],
        })
        
    return artist_map

# %% [markdown]
# # Read Song from DB

# %%
spotify_song, siamzone_song, artist_mapping = None, None, None

with engine.connect() as conn:
    spotify_song = pd.DataFrame.from_dict(song_listing(conn))
    siamzone_song = pd.DataFrame.from_dict(siamzone_listing(conn))
    artist_name_mapping = pd.DataFrame.from_dict(artist_mapping_listing(conn))

# %% [markdown]
# ## Spotify's Song

# %%
spotify_song.set_index('id', inplace=True)

# %%
spotify_song[spotify_song['language'] == 'TH'].head()
# Out:
#                    track_id    artist  \
# id
# 6    4OHu1M6xtQLkgTSao8nYS3  samblack
# 62   6VmtHYkk81yli04paFVxqJ     meyou
# 67   4hccrJgNG1BwPa3CWw4NNg   urboytj
# 129  7tFrJ1JPTVmQKVU5XlGQdb      hers
# 238  7JC59jSvjSbJ2MszeV6fBs    copter
#
#                                                 name  \
# id
# 6                                           ไม่ยินดี
# 62                                   พัทยา (Pattaya)
# 67                                         กอดได้ไหม
# 129                                         ยังคงคอย
# 238  เดี๋ยวเธอกับเขาก็คืนดีกัน Feat. 3rd Tilly Birds
#
#                                            cover_image  \
# id
# 6    https://i.scdn.co/image/ab67616d00004851b12d3e...
# 62   https://i.scdn.co/image/ab67616d0000485119bf48...
# 67   https://i.scdn.co/image/ab67616d000048518b1d41...
# 129  https://i.scdn.co/image/ab67616d00004851c175e7...
# 238  https://i.scdn.co/image/ab67616d00004851a232ea...
#
#                                                   link  \
# id
# 6    https://open.spotify.com/track/4OHu1M6xtQLkgTS...
# 62   https://open.spotify.com/track/6VmtHYkk81yli04...
# 67   https://open.spotify.com/track/4hccrJgNG1BwPa3...
# 129  https://open.spotify.com/track/7tFrJ1JPTVmQKVU...
# 238  https://open.spotify.com/track/7JC59jSvjSbJ2Ms...
#
#                                                  lyric language
# id
# 6                                                 None       TH
# 62   hook, ตกหลุมรักสาวพัทยา, ก็เธอช่างสวยเกินจะจิน...       TH
# 67   VERSE, ไม่ได้มาเรียกร้องอะไร, แค่ต้องการมาใช้ค...       TH
# 129  เธอยังคงคิดถึงบ้างไหม, ในวันที่เรานั้นไกลห่าง,...       TH
# 238                                               None       TH

# %%
spotify_song.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3415 entries, 6 to 3367
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   track_id     3415 non-null   object
#  1   artist       3415 non-null   object
#  2   name         3415 non-null   object
#  3   cover_image  3415 non-null   object
#  4   link         3415 non-null   object
#  5   lyric        356 non-null    object
#  6   language     1112 non-null   object
# dtypes: object(7)
# memory usage: 213.4+ KB

# %%
spotify_song[spotify_song['language'] == 'TH'].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1112 entries, 6 to 3367
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   track_id     1112 non-null   object
#  1   artist       1112 non-null   object
#  2   name         1112 non-null   object
#  3   cover_image  1112 non-null   object
#  4   link         1112 non-null   object
#  5   lyric        342 non-null    object
#  6   language     1112 non-null   object
# dtypes: object(7)
# memory usage: 69.5+ KB

# %%
spotify_song[(spotify_song['language'] == 'TH') & spotify_song['lyric'].isnull()].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 770 entries, 6 to 3367
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   track_id     770 non-null    object
#  1   artist       770 non-null    object
#  2   name         770 non-null    object
#  3   cover_image  770 non-null    object
#  4   link         770 non-null    object
#  5   lyric        0 non-null      object
#  6   language     770 non-null    object
# dtypes: object(7)
# memory usage: 48.1+ KB

# %% [markdown]
# ### Export All

# %%
spotify_song[['track_id', 'artist', 'name']].to_csv('export/label.thai-song.csv')

# %% [markdown]
# ### Export only Thai song

# %%
spotify_song[spotify_song['language'] == 'TH'][['track_id', 'artist', 'name']].to_csv('export/label.thai-song.csv')

# %% [markdown]
# ## Siamzone's Song

# %%
siamzone_song.set_index('id', inplace=True)

# %%
siamzone_song.head()
# Out:
#     song_id artist artist_en                       name  \
# id
# 1         1    001      None                     ฉันสวย
# 2         2    001      None  นาทีที่เจ็ด (นาทีที่เจ็บ)
# 3         3    001      None        ยอมตั้งแต่หน้าประตู
# 4         4   1011      None                   ไม่ไว้ใจ
# 5         5   1011      None               เวลาที่หายไป
#
#                                                 lyric
# id
# 1   ก้น ไม่มี ก้น ไม่มี ก้น ไม่มี, ก็ก้นหนูลาป่วย,...
# 2   กี่พันวันที่ดีครั้งนั้น ถูกทำลายลงหมดไม่เหลือ ...
# 3   หมื่นเหตุผลที่ทิ้งฉันไป กี่พันคำที่เธอคร่ำครวญ...
# 4   บอกเขาว่ายินดี ได้เจอกันสักที ฟังเรื่องเขามามา...
# 5   เช้าทีไรอยากหลับตาไม่ต้องการตื่นขึ้นมา, เจอใคร...

# %% [markdown]
# ## Artist map

# %%
artist_name_mapping.set_index('id', inplace=True)

# %%
artist_name_mapping.head()
# Out:
#                                     artist siamzone_artist
# id
# 22                                     BTS            None
# 23                                 Urworld            None
# 24                           Justin Bieber            None
# 25  Bruno Mars, Anderson .Paak, Silk Sonic            None
# 26                                   TWICE            None

# %% [markdown]
# ## Cleansing artist name
#
# To be sure that we have fresh data we should call `song-manipulator.ipynb` to create `export/name_cleansing.csv` first.

# %%
# %%capture
# %run song-manipulator.ipynb

# %% [markdown]
# ### Reading artist name

# %%
song_cleansing = pd.read_csv('export/name_cleansing.csv')
song_cleansing['song_id'] = song_cleansing['siamzone_id']
song_cleansing['artist'] = song_cleansing['artist'].str.lower()
song_cleansing['title'] = song_cleansing['title'].str.lower()
song_cleansing['mod_title'] = song_cleansing['mod_title'].str.lower()
song_cleansing.set_index('id', inplace=True)
song_cleansing.head()
# Out:
#                   track_id             artist  \
# id
# 18  4tM3ygBuSy0QzB0ihYZQcf  sprite, guygeegee
# 21  19CoWVqDyUbiqxoyMf4HkJ     anatomy rabbit
# 27  2ozCc0MSm3ybXugQqfnKOn   violette wautier
# 31  7ip4DUtdpLH4TkHfKgFbpf      serious bacon
# 7   0JK7pZajOQyfJ2OPxkrWbh            pp krit
#
#                                                 title        mod_title  \
# id
# 18                                                 ทน               ทน
# 21                                      extraordinary    extraordinary
# 27                                             กักตัว           กักตัว
# 31                               1001 (you're lovely)             1001
# 7   หลอกกันทั้งนั้น (fake news) - from "แปลรักฉันด...  หลอกกันทั้งนั้น
#
#                                                  link  has_lyrics  found  \
# id
# 18  https://open.spotify.com/track/4tM3ygBuSy0QzB0...       False   True
# 21  https://open.spotify.com/track/19CoWVqDyUbiqxo...       False   True
# 27  https://open.spotify.com/track/2ozCc0MSm3ybXug...       False   True
# 31  https://open.spotify.com/track/7ip4DUtdpLH4TkH...       False   True
# 7   https://open.spotify.com/track/0JK7pZajOQyfJ2O...        True   True
#
#     siamzone_id  song_id
# id
# 18      19474.0  19474.0
# 21      18445.0  18445.0
# 27      19658.0  19658.0
# 31      19021.0  19021.0
# 7           NaN      NaN

# %%
song_cleansing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 712 entries, 18 to 3270
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   track_id     712 non-null    object
#  1   artist       712 non-null    object
#  2   title        712 non-null    object
#  3   mod_title    712 non-null    object
#  4   link         712 non-null    object
#  5   has_lyrics   712 non-null    bool
#  6   found        712 non-null    bool
#  7   siamzone_id  649 non-null    float64
#  8   song_id      649 non-null    float64
# dtypes: bool(2), float64(2), object(5)
# memory usage: 45.9+ KB

# %% [markdown]
# # Data merging

# %% [markdown]
# ## Artist name mapping

# %%
artist_name_mapping['artist'] = artist_name_mapping['artist'].str.lower()
artist_name_mapping['siamzone_artist'] = artist_name_mapping['siamzone_artist'].str.lower()

# %%
artist_name_mapping[artist_name_mapping.siamzone_artist.notna()].head()
# Out:
#                artist                                    siamzone_artist
# id
# 30  sprite, guygeegee  สไปร์ท ศุกลวัฒน์ พวงสมบัติ\t\t\t\t\t\t\t\t\t\t...
# 32      f.hero, txrbo                                     ฟักกลิ้ง ฮีโร่
# 33      f.hero, txrbo  ฟักกลิ้ง ฮีโร่\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t(f...
# 34      f.hero, txrbo  ฟักกลิ้ง ฮีโร่\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t(f...
# 35      f.hero, txrbo  ฟักกลิ้ง ฮีโร่\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t(f...

# %% [markdown]
# ## Spotify + Artist mapp

# %%
spotify_with_am = pd.merge(
    spotify_song[spotify_song['language'] == 'TH'][[
        'track_id', 
        'artist', 
        'name', 
        'cover_image', 
        'link', 
        'lyric', 
        'language'
    ]], 
    artist_name_mapping[['artist', 'siamzone_artist']],
    how='left',
    on=['artist']
)

# %%
spotify_with_am.head()
# Out:
#                  track_id    artist             name  \
# 0  4OHu1M6xtQLkgTSao8nYS3  samblack         ไม่ยินดี
# 1  6VmtHYkk81yli04paFVxqJ     meyou  พัทยา (Pattaya)
# 2  6VmtHYkk81yli04paFVxqJ     meyou  พัทยา (Pattaya)
# 3  6VmtHYkk81yli04paFVxqJ     meyou  พัทยา (Pattaya)
# 4  6VmtHYkk81yli04paFVxqJ     meyou  พัทยา (Pattaya)
#
#                                          cover_image  \
# 0  https://i.scdn.co/image/ab67616d00004851b12d3e...
# 1  https://i.scdn.co/image/ab67616d0000485119bf48...
# 2  https://i.scdn.co/image/ab67616d0000485119bf48...
# 3  https://i.scdn.co/image/ab67616d0000485119bf48...
# 4  https://i.scdn.co/image/ab67616d0000485119bf48...
#
#                                                 link  \
# 0  https://open.spotify.com/track/4OHu1M6xtQLkgTS...
# 1  https://open.spotify.com/track/6VmtHYkk81yli04...
# 2  https://open.spotify.com/track/6VmtHYkk81yli04...
# 3  https://open.spotify.com/track/6VmtHYkk81yli04...
# 4  https://open.spotify.com/track/6VmtHYkk81yli04...
#
#                                                lyric language  \
# 0                                               None       TH
# 1  hook, ตกหลุมรักสาวพัทยา, ก็เธอช่างสวยเกินจะจิน...       TH
# 2  hook, ตกหลุมรักสาวพัทยา, ก็เธอช่างสวยเกินจะจิน...       TH
# 3  hook, ตกหลุมรักสาวพัทยา, ก็เธอช่างสวยเกินจะจิน...       TH
# 4  hook, ตกหลุมรักสาวพัทยา, ก็เธอช่างสวยเกินจะจิน...       TH
#
#                                      siamzone_artist
# 0                                                NaN
# 1                               มิว ชิษณุชา ตันติเมธ
# 2  มิว ชิษณุชา ตันติเมธ\t\t\t\t\t\t\t\t\t\t\t\t\t...
# 3  มิว ชิษณุชา ตันติเมธ\t\t\t\t\t\t\t\t\t\t\t\t\t...
# 4  มิว ชิษณุชา ตันติเมธ\t\t\t\t\t\t\t\t\t\t\t\t\t...

# %% [markdown]
# ## Song cleansing + Siamzone

# %%
siamzone_song.set_index('id', inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/kw/l_1wnsdx3kvfs59fy591pm400000gn/T/ipykernel_31092/210215815.py in <module>
# ----> 1 siamzone_song.set_index('id', inplace=True)
#
# ~/Projects/SWU/Thesis/music-gathering/venv/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/Projects/SWU/Thesis/music-gathering/venv/lib/python3.7/site-packages/pandas/core/frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    5444
#    5445         if missing:
# -> 5446             raise KeyError(f"None of {missing} are in the columns")
#    5447
#    5448         if inplace:
#
# KeyError: "None of ['id'] are in the columns"

# %%
siamzone_song.sort_values(by=['song_id'], ascending=False).head(20)
# Out:
#        song_id                                             artist  \
# id
# 20387    21785  ซิลวี่ ภาวิดา มอริจจิ\t\t\t\t\t\t\t\t\t\t\t\t\...
# 20386    21784                                    บ.เบิ้ล สามร้อย
# 20385    21783  บี้ เดอะสกา\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t(bie ...
# 20384    21782                                       ใบปอ รัตติยา
# 20383    21781                                   เอกรวี ธีระพันธ์
# 20382    21780                                  ต้นข้าว อาร์ สยาม
# 20381    21779                            เม้ก อภิสิทธิ์ จันทะเสน
# 20380    21778  พีท พิทยา ชูช่วย\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t...
# 20379    21777                                         จูน ธิติยา
# 20378    21776                         โต๋ ศักดิ์สิทธิ์ เวชสุภาพร
# 20377    21775  สไปร์ท ศุกลวัฒน์ พวงสมบัติ\t\t\t\t\t\t\t\t\t\t...
# 20376    21774                                     พราหมณ์ มณีกุล
# 20375    21773    เดอะทอย\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t(the toys)
# 20374    21772                                   ธีเดช ทองอภิชาติ
# 20373    21771      โปเตโต้\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t(potato)
# 20372    21770                                         ตัส ชนะชัย
# 20371    21769                                             ยิวเจน
# 20370    21768  เซเว่นเดย์ เครซี่\t\t\t\t\t\t\t\t\t\t\t\t\t\t\...
# 20369    21767  วี วิโอเลต วอเทียร์\t\t\t\t\t\t\t\t\t\t\t\t\t\...
# 20368    21766  คล็อกเวิร์ก โมชั่นเลส\t\t\t\t\t\t\t\t\t\t\t\t\...
# 20367    21765         วีเคแอล\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t(vkl)
# 20366    21764  นารา วาซาบิ\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t(nara...
# 20365    21763  เอ๊ะ จิรากร สมพิทักษ์\t\t\t\t\t\t\t\t\t\t\t\t\...
# 20364    21762             ฟิน\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t(fin)
# 20363    21761                                              ฝนพรำ
# 20362    21760  แพง พัทธนันท์ อภิวัฒน์เวคิน\t\t\t\t\t\t\t\t\t\...
# 20361    21759                                        เนม สุรพงศ์
# 20360    21758  เอิ๊ต ภัทรวี ศรีสันติสุข\t\t\t\t\t\t\t\t\t\t\t...
# 20359    21757                                           เอ๋ มิรา
# 20358    21756                                       แป้ง ณัฐธิดา
#
#                   artist_en  \
# id
# 20387                 silvy
# 20386                  None
# 20385           bie the ska
# 20384                  None
# 20383                  None
# 20382                  None
# 20381                  None
# 20380            peet model
# 20379                  None
# 20378                  None
# 20377                sprite
# 20376                  None
# 20375              the toys
# 20374                  None
# 20373                potato
# 20372                  None
# 20371                  None
# 20370           7days crazy
# 20369      violette wautier
# 20368  clockwork motionless
# 20367                   vkl
# 20366           nara wazabi
# 20365           ae jirakorn
# 20364                   fin
# 20363                  None
# 20362         pang pattanan
# 20361                  None
# 20360        earth patravee
# 20359                  None
# 20358                  None
#
#                                                     name  \
# id
# 20387                                                 xl
# 20386                             หราง (เวลคัมทูเรือนจำ)
# 20385                               missed call (มิสคอล)
# 20384                                      บ่น่าเสียเวลา
# 20383                                            คืนเมือ
# 20382                                       ใจเหลือเหลือ
# 20381                                        บักพากหัวใจ
# 20380                                       ปล่อยฉันเถอะ
# 20379                                       รักไม่ชัดเจน
# 20378           เป็นของเธอ (ost. หว่ออ้ายหนี่ เธอที่รัก)
# 20377                                          ไม่ต้องทน
# 20376                       อยากให้เธอผ่านพ้นพบเจอสิ่งดี
# 20375                                 เมะ (kiss by kiss)
# 20374                                     ฉันยังจำไม่ลืม
# 20373                                         ทำเป็นเล่น
# 20372                                              ฮำฮอน
# 20371                                     เก็บรักไว้นานๆ
# 20370                                    รอยสักที่ถูกลืม
# 20369               ตั้งแต่มีเธอฉันมีความสุข (this time)
# 20368             เสียใจได้ยินไหม (ost. ลวง ฆ่า ล่า รัก)
# 20367                                              เขียว
# 20366                                        ไม่หล่อครับ
# 20365  อยากให้ช่วงเวลาดีๆ เหล่านี้อยู่กับเราไปนานๆ ได...
# 20364                                      ก็คนมันคิดถึง
# 20363                 เป็นวันที่โคตรเเย่ (ขอเวลาอ่อนเเอ)
# 20362                                   มามาไปไป (herr~)
# 20361                                            เชื่อบ่
# 20360                                                งอน
# 20359                                            ฟ้ามีตา
# 20358                                             คองถ่า
#
#                                                    lyric
# id
# 20387  People, didn't know what I got, People, used t...
# 20386  ไซรู้ว่าผิดก็ยังทำ ไซรู้ว่าปล้ำยังไม่พอ, คำพูด...
# 20385  โทรไปก็ไม่รับสาย กดไม่รู้กี่ร้อยสาย, ทำเหมือนไ...
# 20384  คงเป็นได้แค่ของเก่า, ในเมื่อเขาบ่เอาเฮาแล้ว, ค...
# 20383  ครอบครัว ยังคองทาง, คืนสานาง คืนบ้านเฮา, หากเม...
# 20382  ลำพังรักเธอคนเดียว ทำให้ลำบากใจมากอยู่แล้ว, ยั...
# 20381  ขะเจ้าเเค่เข้ามาคุยนำมึงเล่นๆ ซื่อๆ, เขาบ่ได้จ...
# 20380  คำถามในหัวของฉัน, เป็นร้อยเป็นพันเรื่องเธอ, นี...
# 20379  ความรักในตอนนี้ มันไม่พอดีหรือไม่ดีพอ, ที่เธอใ...
# 20378  เข้าใจ คืนวันที่เปลี่ยนผัน, หนทาง พาเราห่างไกล...
# 20377  พี่ไม่เอา Louis Vuitton, จะเคลียร์หนี้ก้อนโต, ...
# 20376  มีแต่ความคิดถึง ข้างในคืนนี้มีเพียงแต่เขา, หาก...
# 20375  ถ้าเธอเลิกกับเขาแล้ว, กลับมาหานะ, อุตส่าห์เป็น...
# 20374  คิดถึงและเป็นห่วง, ยอดดวงใจของพี่, นั้นอยู่แห่...
# 20373  เดินมาไกลเท่าไรไม่รู้, มันเป็นเรื่องเมื่อวาน, ...
# 20372  เฮ็ดอิหยังอยู่น้อ กินข้าวแล้วไป่นอ, ไปเฮ็ดงานเ...
# 20371  อบอุ่นใจเสมอเมื่อเธอชิดใกล้, เธอไม่เหมือนกับใค...
# 20370  ใครบางคนหมดรักก็เลิกกันไป, ลืมคนเดิมพรุ่งนี้ก็...
# 20369  ที่ผ่านมา ฉันพบแต่รักที่ทำ ให้เสียใจ, เจอแต่ ค...
# 20368  เพราะว่ารัก จึงเปรียบเธอนั้น เป็นดั่งชีวิต, ก็...
# 20367  เช็กของก่อนโอเคเหนียว, กูผอมเเต่เเข็งเเรง Pop ...
# 20366  แต่ผมนั่นจริงใจ, ไม่รวยครับ แต่ว่าผมจะไม่มีใคร...
# 20365  ทุกครั้งที่เราได้เจอกันนั้นช่างแสนสุขใจ, เฝ้าแ...
# 20364  อยากตะโกนดังๆ ให้เธอเห็นใจ, เธอจะได้ยินหม้าย ฉ...
# 20363  วันนี้ใจอ่อนแอ ท้อแท้ให้กับทุกอย่าง, มีเสียงเพ...
# 20362  ในคืนที่เกือบจะเช้า เดียวดายกับความเงียบเหงา, ...
# 20361  ว่าอ้ายยังอยู่หม่องเก่า, เชื่อบ่ ว่าตั้งแต่เฮา...
# 20360  จงง้อ จงง้อ จงง้อ ต้องง้อ จงง้อ จงง้อ, โทรไม่โ...
# 20359  หลายปีที่ทนรอคอย มันมาถึงแล้ว, หลายปีที่แอบมีค...
# 20358  ม่านหมอก โปรยปราย, ดั่งสายน้ำตาจากฟ้าเหมันต์, ...

# %%
song_cleansing.head()
# Out:
#                   track_id             artist  \
# id
# 18  4tM3ygBuSy0QzB0ihYZQcf  sprite, guygeegee
# 21  19CoWVqDyUbiqxoyMf4HkJ     anatomy rabbit
# 27  2ozCc0MSm3ybXugQqfnKOn   violette wautier
# 31  7ip4DUtdpLH4TkHfKgFbpf      serious bacon
# 7   0JK7pZajOQyfJ2OPxkrWbh            pp krit
#
#                                                 title        mod_title  \
# id
# 18                                                 ทน               ทน
# 21                                      extraordinary    extraordinary
# 27                                             กักตัว           กักตัว
# 31                               1001 (you're lovely)             1001
# 7   หลอกกันทั้งนั้น (fake news) - from "แปลรักฉันด...  หลอกกันทั้งนั้น
#
#                                                  link  has_lyrics  found  \
# id
# 18  https://open.spotify.com/track/4tM3ygBuSy0QzB0...       False   True
# 21  https://open.spotify.com/track/19CoWVqDyUbiqxo...       False   True
# 27  https://open.spotify.com/track/2ozCc0MSm3ybXug...       False   True
# 31  https://open.spotify.com/track/7ip4DUtdpLH4TkH...       False   True
# 7   https://open.spotify.com/track/0JK7pZajOQyfJ2O...        True   True
#
#     siamzone_id  song_id
# id
# 18      19474.0  19474.0
# 21      18445.0  18445.0
# 27      19658.0  19658.0
# 31      19021.0  19021.0
# 7           NaN      NaN

# %%
spotify_with_am.head()
# Out:
#                  track_id    artist             name  \
# 0  4OHu1M6xtQLkgTSao8nYS3  samblack         ไม่ยินดี
# 1  6VmtHYkk81yli04paFVxqJ     meyou  พัทยา (Pattaya)
# 2  6VmtHYkk81yli04paFVxqJ     meyou  พัทยา (Pattaya)
# 3  6VmtHYkk81yli04paFVxqJ     meyou  พัทยา (Pattaya)
# 4  6VmtHYkk81yli04paFVxqJ     meyou  พัทยา (Pattaya)
#
#                                          cover_image  \
# 0  https://i.scdn.co/image/ab67616d00004851b12d3e...
# 1  https://i.scdn.co/image/ab67616d0000485119bf48...
# 2  https://i.scdn.co/image/ab67616d0000485119bf48...
# 3  https://i.scdn.co/image/ab67616d0000485119bf48...
# 4  https://i.scdn.co/image/ab67616d0000485119bf48...
#
#                                                 link  \
# 0  https://open.spotify.com/track/4OHu1M6xtQLkgTS...
# 1  https://open.spotify.com/track/6VmtHYkk81yli04...
# 2  https://open.spotify.com/track/6VmtHYkk81yli04...
# 3  https://open.spotify.com/track/6VmtHYkk81yli04...
# 4  https://open.spotify.com/track/6VmtHYkk81yli04...
#
#                                                lyric language  \
# 0                                               None       TH
# 1  hook, ตกหลุมรักสาวพัทยา, ก็เธอช่างสวยเกินจะจิน...       TH
# 2  hook, ตกหลุมรักสาวพัทยา, ก็เธอช่างสวยเกินจะจิน...       TH
# 3  hook, ตกหลุมรักสาวพัทยา, ก็เธอช่างสวยเกินจะจิน...       TH
# 4  hook, ตกหลุมรักสาวพัทยา, ก็เธอช่างสวยเกินจะจิน...       TH
#
#                                      siamzone_artist
# 0                                                NaN
# 1                               มิว ชิษณุชา ตันติเมธ
# 2  มิว ชิษณุชา ตันติเมธ\t\t\t\t\t\t\t\t\t\t\t\t\t...
# 3  มิว ชิษณุชา ตันติเมธ\t\t\t\t\t\t\t\t\t\t\t\t\t...
# 4  มิว ชิษณุชา ตันติเมธ\t\t\t\t\t\t\t\t\t\t\t\t\t...

# %%
siamzone_song[siamzone_song['name'] == "ทน"]
# Out:
#        song_id                                             artist artist_en  \
# id
# 19504    20898  สไปร์ท ศุกลวัฒน์ พวงสมบัติ\t\t\t\t\t\t\t\t\t\t...    sprite
#
#       name                                              lyric
# id
# 19504   ทน  พี่ไม่มี Louis Vuitton มีแต่หนี้ก้อนโต, นวลน้อ...

# %%
spotify_with_am[
    ~spotify_with_am['siamzone_artist'].isnull()
    &
    (
        spotify_with_am['siamzone_artist'].str.contains('มิว ชิษณุชา ตันติเมธ')
        |
        spotify_with_am['artist'].str.contains('มิว ชิษณุชา ตันติเมธ')
    )
    &
    spotify_with_am['name'].str.contains('พัทยา')
    &
    spotify_with_am['lyric'].isnull()
]
# Out:
# Empty DataFrame
# Columns: [track_id, artist, name, cover_image, link, lyric, language, siamzone_artist]
# Index: []

# %%
def update_lyric(track_ids, lyric):
    if None == lyric:
        return
    
    for track_id in track_ids:
        spotify_with_am.loc[track_id == spotify_with_am['track_id'], 'lyric'] = lyric

# %%
# import warnings
# warnings.filterwarnings("ignore", 'This pattern has match groups')
i = 1
for _, t in siamzone_song.iterrows():
    sp_am = spotify_with_am[
        ~spotify_with_am['siamzone_artist'].isnull()
        &
        (
            spotify_with_am['siamzone_artist'].str.contains(t['artist'], regex=False)
            |
            spotify_with_am['artist'].str.contains(t['artist'], regex=False)
        )
        &
        spotify_with_am['name'].str.contains(t['name'], regex=False)
        &
        spotify_with_am['lyric'].isnull()
        &
        (spotify_with_am['language'] == 'TH')
    ]
    
    if not sp_am.empty:
        print(f'{i}.', t['artist'], '-', t['name'], end=" => ")
        update_lyric(track_ids=sp_am['track_id'].to_list(), lyric=t['lyric'])
        print('Done', len(t['lyric']) if t['lyric'] else 0)
        i += 1
# Out:
# 1. ซิลลี่ ฟูลส์ - ขี้หึง => Done 1093
# 2. โซฟา - เรื่องมหัศจรรย์ => Done 883
# 3. ดา เอ็นโดรฟิน - คืนข้ามปี => Done 815
# 4. ตู่ ภพธร สุนทรญาณกิจ - ถ้าหาก => Done 1066
# 5. บิ๊กแอส & บอดี้สแลม - เรา => Done 898
# 6. บุดดาเบลส - ลืมไปก่อน => Done 1470
# 7. ปราโมทย์ วิเลปะนะ - คืนที่ดาวเต็มฟ้า => Done 843
# 8. โปเตโต้ - เธอยัง... => Done 1396
# 9. พอส															(pause) - ดาว => Done 1030
# 10. แพนเค้ก - ใจเย็น => Done 1678
# 11. มัสคีเทียร์ - ไกล => Done 1546
# 12. มัสคีเทียร์ - ของขวัญ => Done 1314
# 13. มัสคีเทียร์ - ความทรงจำ => Done 1027
# 14. โรส ศิรินทิพย์ หาญประดิษฐ์ - ปีใหม่ใหม่ => Done 1220
# 15. สิงโต นำโชค - เธอคือของขวัญ => Done 888
# 16. แสตมป์ อภิวัชร์ เอื้อถาวรสุข - คนที่คุณก็รู้ว่าใคร => Done 1086
# 17. อีทีซี - เจ้าชายนิทรา => Done 961
# 18. เอิ้น พิยะดา หาชัยภูมิ - ทำไมต้องรักเธอ => Done 1342
# 19. พาราด็อกซ์ - คนบนฟ้า => Done 969
# 20. วัชราวลี - ร่มสีเทา => Done 1225
# 21. วัชราวลี															(whatcharawalee) - ลูกอม => Done 1236
# 22. โพลีแคท - ลา => Done 1103
# 23. วัชราวลี - ทราย => Done 964
# 24. สิงโต นำโชค - อยู่ต่อเลยได้ไหม => Done 1322
# 25. รุจ ศุภรุจ เตชะตานนท์ - กะทันหัน => Done 1497
# 26. เบดรูม ออดิโอ															(bedroom audio) - กอดไม่ได้ => Done 860
# 27. วัชราวลี - น้อย => Done 1058
# 28. ค็อกเทล - เธอ => Done 1018
# 29. ป๊อบ ปองกูล สืบซึ้ง - ปล่อย => Done 727
# 30. แสตมป์ อภิวัชร์ เอื้อถาวรสุข - กาลครั้งหนึ่ง => Done 1319
# 31. วัชราวลี - สถานีดวงจันทร์ => Done 1532
# 32. ค็อกเทล - คู่ชีวิต => Done 1413
# 33. ต้น ธนษิต จตุรภุช - รู้ยัง => Done 1289
# 34. ละอองฟอง - คนที่ฟ้าส่งมาให้รักกัน => Done 1250
# 35. แอมมี่ ไชยอมร แก้ววิบูลย์พันธุ์															(ammy) - เก็บรัก => Done 853
# 36. ลาบานูน															(labanoon) - แพ้ทาง => Done 1132
# 37. อิลสลิก															(illslick) - รักเมียที่สุดในโลก => Done 1628
# 38. ป้าง นครินทร์ กิ่งศักดิ์ - คนมีเสน่ห์ => Done 1316
# 39. บอย โกสิยพงษ์															(boyd kosiyabong) - ไม่ว่าเมื่อไหร่ => Done 1573
# 40. อะตอม ชนกันต์ รัตนอุดม															(atom) - อ้าว => Done 1297
# 41. ลุลา															(lula) - เรื่องที่ขอ => Done 1106
# 42. เดอะทอย															(the toys) - หน้าหนาวที่แล้ว => Done 2005
# 43. เดอะทอย															(the toys) - จดหมาย => Done 962
# 44. เดอะ มูสส์															(the mousses) - หลอกให้รัก => Done 972
# 45. โอ๊ต ปราโมทย์ ปาทาน - เมื่อวาน => Done 1052
# 46. ซิน ทศพร อาชวานันทกุล															(sin) - เธอเปลี่ยนไปแล้ว => Done 1316
# 47. อิ้งค์ วรันธร เปานิล - ฉันต้องคิดถึงเธอแบบไหน => Done 1082
# 48. ยัวร์บอยทีเจ															(urboytj) - ไม่อยากฟัง => Done 1713
# 49. นนท์ ธนนท์ จำเริญ - ฝืนตัวเองไม่เป็น => Done 1466
# 50. เดอะทอย															(the toys) - ก่อนฤดูฝน => Done 988
# 51. ปาล์มมี่															(palmy) - นวด => Done 1812
# 52. โปเตโต้															(potato) - เธอทำให้ได้รู้ => Done 1271
# 53. เดอะ มูสส์															(the mousses) - อย่าเพิ่งใจร้าย => Done 1721
# 54. สงกรานต์ รังสรรค์ ปัญญาเรือน - โอ้เธอ => Done 1254
# 55. วี วิโอเลต วอเทียร์															(violette wautier) - ก็แค่ไม่มีฉัน => Done 758
# 56. แจ๊ส สปุ๊กนิค ปาปิยอง กุ๊กกุ๊ก - มือลั่น => Done 1371
# 57. มิ้นท์ ภัทรศยา ยงรัตนมงคล - พบเธอก่อน => Done 997
# 58. เบดรูม ออดิโอ															(bedroom audio) - รอ => Done 1124
# 59. เบน ชลาทิศ ตันติวุฒิ - ยังรอ => Done 776
# 60. เพชร สหรัตน์ - เจ็บละเนาะ => Done 932
# 61. เป๊ก ผลิตโชค อายนบุตร - โทษที่เอาแต่ใจ (sorry) => Done 1883
# 62. โต๋ ศักดิ์สิทธิ์ เวชสุภาพร - เวลาของเรา => Done 1364
# 63. นิว & จิ๋ว															(newjiew) - ถ้าฉันได้กลับไป => Done 1095
# 64. ค็อกเทล															(cocktail) - ทำดีไม่เคยจำ => Done 1412
# 65. เอ๊ะ จิรากร สมพิทักษ์ - ปาใส่หน้า => Done 857
# 66. อุ๋ย นที เอกวิจิตร - ใช่มั้ย? => Done 1689
# 67. ป้าง นครินทร์ กิ่งศักดิ์ - ทุกคนเคยร้องไห้ => Done 993
# 68. ชาติ สุชาติ แซ่เห้ง - เพียง => Done 960
# 69. แบงค์ ปรีติ บารมีอนันต์															(bankk cash) - บทสุดท้าย => Done 1478
# 70. โอ๊ต ปราโมทย์ ปาทาน - มีแฟนแล้ว => Done 1811
# 71. โต๋ ศักดิ์สิทธิ์ เวชสุภาพร - รอยยิ้มของวันพรุ่งนี้ => Done 1262
# 72. พลพล พลกองเส็ง - ใครคนนั้น => Done 1103
# 73. โอปอ ประพุทธ์ พิมพามา - เวลา => Done 1169
# 74. ค็อกเทล															(cocktail) - ปรารถนาสิ่งใดฤๅ => Done 1292
# 75. อะตอม ชนกันต์ รัตนอุดม															(atom) - อย่าบอก => Done 807
# 76. เดอะทอย															(the toys) - ขอโทษที่เป็นแบบนี้ => Done 762
# 77. อีทีซี															(etc) - ฝัง (ใน) ใจ => Done 694
# 78. ลุลา - เรื่องระหว่างทาง => Done 1173
# 79. ตู่ ภพธร สุนทรญาณกิจ - แต่ยังคิดถึง => Done 1253
# 80. เยสเซอร์เดย์															(yes'sir days) - คำตอบที่เธอเลือก => Done 1123
# 81. เบิร์ด ธงไชย แมคอินไตย์ - พริบตา => Done 1480
# 82. ว่าน ธนกฤต พานิชวิทย์ - แก.. => Done 1108
# 83. แจ๊ส สปุ๊กนิค ปาปิยอง กุ๊กกุ๊ก															(jspkk) - หัวร้อน => Done 1325
# 84. เต้ ดาวิชญ์ & ตี๋ ธนพล															(tae tee) - ใช่หรือเปล่า => Done 1095
# 85. มิว ชิษณุชา ตันติเมธ															(meyou.) - พอจะรู้ => Done 898
# 86. พิลส์															(pills) - ฝากดาว => Done 580
# 87. เบิร์ด ธงไชย แมคอินไตย์ - ชีวิตเดี่ยว => Done 1174
# 88. โต๋ ศักดิ์สิทธิ์ เวชสุภาพร - เก็บรักคืนมา => Done 1090
# 89. เบิร์ด ธงไชย แมคอินไตย์ - ผู้ต้องหา => Done 1702
# 90. ปาล์มมี่															(palmy) - แม่เกี่ยว => Done 1747
# 91. เดอะทอย															(the toys) - 04:00 => Done 1176
# 92. แอมมี่ ไชยอมร แก้ววิบูลย์พันธุ์															(ammy the bottom blues) - โตแล้ว => Done 807
# 93. นัน สุนันทา ยูรนิยม															(nann) - ฉันก็ยังจะบอกรักเธอ => Done 941
# 94. บอย พีซเมกเกอร์															(boy peacemaker) - เธอเปลี่ยนไป => Done 1159
# 95. เบล สุพล พัวศิริรักษ์ - ทรมานตัวเอง => Done 1815
# 96. บีไฟว์															(b5) - วีนัส => Done 1307
# 97. โพลีแคท															(polycat) - ผู้ช่วยที่ดีที่สุด => Done 1504
# 98. สมเกียรติ															(somkiat) - ขอเถอะปีนี้ => Done 749
# 99. ป๊อบ ปองกูล สืบซึ้ง - ภาพจำ => Done 1385
# 100. หนุ่ม กะลา															(num kala) - แอบ => Done 844
# 101. พอส															(pause) - คนที่แสนธรรมดา => Done 1237
# 102. มาร์ค ธัชพล จุลเกษม															(marc) - ที่เก่า => Done 1391
# 103. เดอะ เยอร์ส															(the yers) - เกลียด => Done 724
# 104. มิว ชิษณุชา ตันติเมธ															(meyou.) - อีกแล้ว => Done 1239
# 105. โอ๊ต ปราโมทย์ ปาทาน - คิดถึงจัง (มาหาหน่อย) => Done 988
# 106. ซิกส์ตี้ ไมลส์															(60 miles) - ผิดที่ฉัน => Done 827
# 107. เบิร์ด ธงไชย แมคอินไตย์															(bird thongchai) - กว่าจักรวาล => Done 968
# 108. แบงค์ ปรีติ บารมีอนันต์															(bankk cash) - รอฉันหรือเปล่า => Done 842
# 109. แสตมป์ อภิวัชร์ เอื้อถาวรสุข															(stamp) - ร้อยล้านวิว => Done 1036
# 110. เบิร์ด ธงไชย แมคอินไตย์															(bird thongchai) - พี่เปิดให้ => Done 1347
# 111. พีธ พีราวัชร์ อัศรววชิรวิท - กอดที่ว่างเปล่า => Done 845
# 112. สิงโต นำโชค - อย่าร้องไห้ => Done 1107
# 113. เยิ้ม															(yerm) - ที่ผ่านมา => Done 698
# 114. โอ ปวีร์ คชภักดี															(o pavee) - คนที่ไม่ใช่ => Done 1076
# 115. โอปอ ประพุทธ์ พิมพามา - ควันเหงา => Done 1132
# 116. เบิร์ด ธงไชย แมคอินไตย์															(bird thongchai) - กำแพง => Done 1297
# 117. แสตมป์ อภิวัชร์ เอื้อถาวรสุข															(stamp) - ฝันหวานอายจูบ => Done 1380
# 118. ลุลา															(lula) - เราไม่รู้จักกัน => Done 977
# 119. รุจ ศุภรุจ เตชะตานนท์															(ruj suparuj) - รักในใจ => Done 884
# 120. ลิปตา															(lipta) - หมอกร้าย => Done 1711
# 121. เดอะทอย															(the toys) - ของขวัญ => Done 1005
# 122. ลิปตา															(lipta) - คิดถึงเสมอ => Done 885
# 123. กันต์ ชุณหวัตร - ยินดีที่ได้พบ => Done 859
# 124. เบิร์ด ธงไชย แมคอินไตย์															(bird thongchai) - สิ้นสุดคือจุดเริ่มต้น => Done 1074
# 125. ซูเปอร์ซับ															(supersub) - ...ก่อน => Done 775
# 126. บีไฟว์															(b5) - เห็นฉันไหม => Done 1114
# 127. ตูน บอดี้แสลม - ใส่ใจ => Done 1110
# 128. ฟิกส์ &ไมยราพ & ยังโอม															(fiixd x maiyarap x youngohm) - กอดฉัน => Done 2280
# 129. ว่าน ธนกฤต พานิชวิทย์ - โสดทัศนศึกษา => Done 1660
# 130. เอ๊ะ จิรากร สมพิทักษ์ - ตราบที่ยังหายใจ => Done 843
# 131. บุรินทร์ บุญวิสุทธิ์ - ขอโทษ => Done 1013
# 132. แก้ม วิชญาณี เปียกลิ่น - ไม่มีเธอไม่ตาย => Done 2303
# 133. กวินท์ ดูวาล															(gavin d) - เกาะสวาทหาดสวรรค์ => Done 1950
# 134. เก่ง ธชย ประทุมวรรณ - แบบไหนที่ว่าดี บอกทีจะได้ทำ => Done 1685
# 135. ยังกู															(younggu) - วิ่งแบบพี่ตูน => Done 2754
# 136. นนท์ ธนนท์ จำเริญ - มีผลต่อหัวใจ => Done 1380
# 137. อินดิโก้															(indigo) - แค่เราไม่ได้รักกัน => Done 1012
# 138. บีไฟว์															(b5) - แผลเป็น => Done 1397
# 139. เบล สุพล พัวศิริรักษ์ - เพราะเธอ => Done 1103
# 140. โอ ปวีร์ คชภักดี															(o pavee) - โคตรจะภักดี => Done 994
# 141. ค็อกเทล															(cocktail) - เงาของเมื่อวาน => Done 1147
# 142. อะตอม ชนกันต์ รัตนอุดม															(atom) - รถคันเก่า => Done 1176
# 143. โปเตโต้															(potato) - เท่าไหร่ไม่จำ => Done 913
# 144. พีฮอต วัชรินทร์ พึ่งสุข															(p-hot) - เบอร์มาดิ => Done 3483
# 145. ชาติ สุชาติ แซ่เห้ง - ที่เหลือ => Done 984
# 146. แสตมป์ อภิวัชร์ เอื้อถาวรสุข															(stamp) - ภูเขาบังเส้นผม => Done 1673
# 147. บอดี้สแลม															(bodyslam) - วิชาตัวเบา => Done 1059
# 148. บิ๊กแอส															(big ass) - ตลอดไป...มีจริง => Done 1071
# 149. บิ๊ก ภูวดิท ศิลาอุดมเดช															(og-anic) - ทุ่มหมดตัว => Done 1849
# 150. โทนี่ ผี - วินาทีที่เธอไป => Done 1654
# 151. เอิ๊ต ภัทรวี ศรีสันติสุข															(earth patravee) - ไม่ให้เธอหายไป => Done 1096
# 152. น้อย กฤษฎา สุโกศล แคลปป์ - แด่ศาลที่เคารพ => Done 751
# 153. แคลช															(clash) - ใจเย็นเย็น => Done 1756
# 154. บีไฟว์															(b5) - บีบมือ => Done 1096
# 155. เอนัน ศิริศักดิ์ เลขวัฒนะโรจน์															(ironboy) - ก็ดี.. => Done 1983
# 156. แอมมี่ ไชยอมร แก้ววิบูลย์พันธุ์															(ammy the bottom blues) - สมดั่งใจ => Done 1170
# 157. โอ๊ต ปราโมทย์ ปาทาน - ติดตลก => Done 1078
# 158. เวย์ ปริญญา อินทชัย															(daboyway) - มอง => Done 2100
# 159. มาร์ค ธัชพล จุลเกษม - ด้วยความยินดี => Done 1000
# 160. แบล็คเฮด															(blackhead) - ไม่บอก => Done 1299
# 161. บิ๊ก ภูวดิท ศิลาอุดมเดช															(og-anic) - เป็นไรไหม => Done 2073
# 162. สงกรานต์ รังสรรค์ ปัญญาเรือน - ไม่มีเงื่อนไข => Done 1032
# 163. บอดี้สแลม															(bodyslam) - แสงสวรรค์ => Done 1144
# 164. ลุลา															(lula) - ไม่อยู่ในชีวิตแต่อยู่ในหัวใจ => Done 1173
# 165. เบ็ตเทอร์ เว็ตเทอร์															(better weather) - ไม่เกี่ยวเลย => Done 1031
# 166. อะตอม ชนกันต์ รัตนอุดม															(atom) - หนึ่งคืน => Done 811
# 167. โอ๊ต ปราโมทย์ ปาทาน - งู้ยยยยยยยยยยย => Done 1374
# 168. นนท์ ธนนท์ จำเริญ - ความรักกำลังก่อตัว => Done 1444
# 169. ปาล์มมี่															(palmy) - ซ่อนกลิ่น => Done 851
# 170. ฟักกลิ้ง ฮีโร่															(fukking hero) - เสือสิ้นลาย => Done 2859
# 171. กบ ณัฐพงศ์ ยิ้มมงคล - หา => Done 1191
# 172. เบดรูม ออดิโอ															(bedroom audio) - รักมือสอง => Done 952
# 173. เดอะทอย															(the toys) - ลาลาลอย (100%) => Done 1076
# 174. แร็ปอะเกนสต์ดิกเทเทอร์ชิป															(rap against dictatorship) - ประเทศกูมี => Done 3481
# 175. บีเอ็นเค 48															(bnk48) - 365 วันกับเครื่องบินกระดาษ => Done 1703
# 176. กวินท์ ดูวาล															(gavin d) - ฉันยังไหว => Done 1163
# 177. เดอะทอย															(the toys) - พูดไม่ออก => Done 1036
# 178. บอดี้สแลม															(bodyslam) - ครึ่งๆ กลางๆ => Done 1129
# 179. เดอะทอย															(the toys) - เวลาขับรถ => Done 956
# 180. โต๋ ศักดิ์สิทธิ์ เวชสุภาพร - ยิ้มก็พอ => Done 1380
# 181. คชา นนทนันท์ อัญชุลีประดิษฐ์ - คนเคยรัก => Done 1927
# 182. อ๊อฟ ปองศักดิ์ รัตนพงษ์ - หยุดทีได้ไหม => Done 1279
# 183. ป๊อป อภิวัฒน์ ชินอักษร															(sirpoppa) - ใจบาง => Done 2053
# 184. บิ๊ก ภูวดิท ศิลาอุดมเดช															(og-anic) - ครั้งสุดท้าย => Done 2045
# 185. ทเวนตี้ไฟว์ อาวเวอร์ส															(25hours) - ลืมกันแล้วหรือยัง => Done 705
# 186. แคลช															(clash) - อยู่ตรงนี้เสมอ => Done 1339
# 187. เบ็ตเทอร์ เว็ตเทอร์															(better weather) - เดา => Done 925
# 188. กีต้าร์ มานะ สุวรรณฤกษ์															(gtk) - แพ้ => Done 1231
# 189. เดอะ มูสส์															(the mousses) - ฉันไม่ดีหรือเธอ... => Done 994
# 190. ไซยาไนซ์															(cyanide) - เพ้อ เพ้อ เพ้อ => Done 1988
# 191. อะตอม ชนกันต์ รัตนอุดม - คุณได้ไปต่อ => Done 1048
# 192. บอดี้สแลม															(bodyslam) - 149.6 => Done 932
# 193. วัชราวลี															(whatcharawalee) - แก่อีกแล้ว => Done 1012
# 194. ดับเบิ้ลพี															(double p) - ชนดิ => Done 2074
# 195. ชิตสวิฟท์															(chitswift) - ต้องการฉันไหม => Done 2143
# 196. เจ้านาย จินเจษฎ์ วรรธนะสิน															(jaonaay) - คืนที่ดาวเต็มฟ้า => Done 1127
# 197. ทรี แมน ดาวน์															(three man down) - ตอนไม่ได้เจอ => Done 1088
# 198. เก่ง ธชย ประทุมวรรณ - บังคับ => Done 1245
# 199. บอดี้สแลม															(bodyslam) - นิรันดร์ => Done 1078
# 200. ฟักกลิ้ง ฮีโร่															(fukking hero) - มีแค่เรา => Done 2606
# 201. อะตอม ชนกันต์ รัตนอุดม															(atom) - พอ => Done 1163
# 202. บอย พีซเมกเกอร์															(boy peacemaker) - ไม่ไหวบอกไหว => Done 1073
# 203. มาร์ค ธัชพล จุลเกษม															(marc tatchapon) - เอาไงดีว้า => Done 1575
# 204. เดอะทอย															(the toys) - มีเธอทุกวันก็โอนิ => Done 883
# 205. วาลิน x ซีทริป															(varinz x z trip) - ถามหน่อย => Done 2049
# 206. เบ็ตเทอร์ เว็ตเทอร์															(better weather) - รักทุกวัน => Done 834
# 207. ปาล์มมี่															(palmy) - คิดถึง => Done 1020
# 208. โบกี้ไลอ้อน															(bowkylion) - คนไข้ => Done 1374
# 209. เบดรูม ออดิโอ															(bedroom audio) - คืนข้างแรม => Done 732
# 210. เดอะทอย, จินตหรา พูนลาภ, ฟักกลิ้ง ฮีโร่, บูม บูม แคช - รอไร => Done 2300
# 211. 9x9 (ไนน์ บาย นาย)															(nine by nine) - ไม่น่าเจอเลย (shouldn't) => Done 1376
# 212. บิ๊ก ภูวดิท ศิลาอุดมเดช															(og-anic) - รอสายคนโสด => Done 1387
# 213. โอม รัธพงศ์ ภูรีสิทธิ์															(youngohm) - รถด่วนขบวนสุดท้าย => Done 1290
# 214. โต๋ ศักดิ์สิทธิ์ เวชสุภาพร - รักเลยได้มั้ย? => Done 2053
# 215. กบ ณัฐพงศ์ ยิ้มมงคล															(kob flat boy) - ขวัญใจด่านตรวจ => Done 2333
# 216. เป๊ก ผลิตโชค x ฮอลลาโฟนิก															(peck palitchoke x hollaphonic) - ไม่อยากให้กลับ => Done 1145
# 217. มียู x ยัวร์บอยทีเจ															(meyou x urboytj) - ปล่อยเธอไป => Done 1344
# 218. ลิลลี่ ได้หมดถ้าสดชื่น - เลิกคุยทั้งอำเภอเพื่อเธอคนเดียว => Done 1173
# 219. กวินท์ ดูวาล															(gavin d) - ฝันที่อยู่ในฝัน => Done 2193
# 220. ลุลา															(lula) - มีเหมือนไม่มี => Done 1091
# 221. อิมเมจ สุธิตา ชนะชัยสุวรรณ															(image) - เหงา => Done 713
# 222. วาลิน x ซีทริป x ขนม															(varinz x z trip x kanom) - เอ็นดู => Done 2510
# 223. นานา ภัทรวรินทร์ ซู															(nana) - ได้เปล่า? => Done 2135
# 224. ชิลลิ่ง ซันเดย์															(chilling sunday) - พี่น้อง => Done 1355
# 225. ป๊อป อภิวัฒน์ ชินอักษร															(sirpoppa) - ในฐานะอะไรก็ได้ => Done 1694
# 226. โอม รัธพงศ์ ภูรีสิทธิ์															(youngohm) - คนเดียว บางที => Done 1262
# 227. แสตมป์ อภิวัชร์ เอื้อถาวรสุข															(stamp) - ทั้งจำทั้งปรับ => Done 1397
# 228. โต๋ ศักดิ์สิทธิ์ เวชสุภาพร - เขตห้ามหวง => Done 1133
# 229. เขียนไขและวานิช - แก้มน้องนางนั้นแดงกว่าใคร => Done 1135
# 230. เคลียร์ x ไผ่ พงศธร - ให้นานกว่าที่เคย => Done 1146
# 231. เด็กเลี้ยงควาย - คืนนี้มีสักคนไหมที่ไม่เมา => Done 1785
# 232. ส้ม มารี เออเจนี เลอเลย์ - รางวัลปลอบใจ => Done 1754
# 233. โอ ปวีร์ คชภักดี															(o pavee) - เจ็บไม่จำ => Done 897
# 234. ป้าง นครินทร์ กิ่งศักดิ์ - กรรม => Done 1088
# 235. เอิ๊ต ภัทรวี ศรีสันติสุข - ขอโทษดาว => Done 974
# 236. สิงโต นำโชค - วันที่เรานับหนึ่ง => Done 1084
# 237. อะตอม ชนกันต์ รัตนอุดม															(atom) - แสนสุข => Done 1006
# 238. บอดี้สแลม															(bodyslam) - ไม่แก่ตาย => Done 1572
# 239. แอมมี่ ไชยอมร แก้ววิบูลย์พันธุ์															(ammy the bottom blues) - เสี่ยว => Done 1363
# 240. ค็อกเทล															(cocktail) - เรา => Done 1326
# 241. อ๊อฟ ปองศักดิ์ รัตนพงษ์ - อยากให้เธอเจอคนแบบเธอ => Done 1381
# 242. เฟลโล่ว-เฟลโล่ว															(fellow fellow) - ไม่สนิทอย่าทัก => Done 1456
# 243. มาร์ค ธัชพล จุลเกษม															(marc tatchapon) - มาตรฐานสูง => Done 1053
# 244. ลิปตา															(lipta) - นี่ฉันเอง => Done 1886
# 245. ดี เจอราร์ด															(d gerrard) - รัตติกาล => Done 1797
# 246. ไมยราพ															(maiyarap) - เลือดพ่อแรง => Done 2432
# 247. โต๋ ศักดิ์สิทธิ์ เวชสุภาพร - เราได้เจอกันแล้ว => Done 969
# 248. ออแกนิก x โมนา															(og-anic x mona) - ไม่ว่าง => Done 1738
# 249. ว่าน ธนกฤต พานิชวิทย์ - เดคิสุงิ => Done 1159
# 250. ป๊อก ภัสสรกรณ์, มาร์กี้ ราศรี															(mindset x margie) - มีแต่เธอในหัวใจ => Done 1225
# 251. ปาล์มมี่															(palmy) - ดวงใจ => Done 1099
# 252. หนุ่ม กะลา - สบายดีหรือ => Done 1088
# 253. แสตมป์ อภิวัชร์ เอื้อถาวรสุข															(stamp) - แอบดี => Done 1106
# 254. โพลีแคท															(polycat) - มานี่มา => Done 1005
# 255. เคลียร์, ญาญ่า อุรัสยา															(klear, yaya) - ทัชที่ดีต่อใจ => Done 1243
# 256. ตู่ ภพธร สุนทรญาณกิจ - ยิ่งไกลยิ่งชัด => Done 953
# 257. ค็อกเทล															(cocktail) - พบพาน => Done 1422
# 258. บอดี้สแลม															(bodyslam) - เช้าที่ดวงอาทิตย์ไม่เคยส่องแสง => Done 1088
# 259. ปาล์มมี่															(palmy) - เคว้ง => Done 759
# 260. แก้ม วิชญาณี เปียกลิ่น - รักไปทำไม => Done 1231
# 261. ดี เจอราร์ด															(d gerrard) - คู่หู => Done 1826
# 262. สวีท มัลเลท															(sweet mullet) - ชีวิตหลังเอ่ยคำลา => Done 992
# 263. ส้ม มารี เออเจนี เลอเลย์ - โลกอีกใบ => Done 963
# 264. กวินท์ ดูวาล															(gavin.d) - รักได้ป่าว => Done 1727
# 265. กวินท์ ดูวาล - กอด => Done 1729
# 266. หนุ่ม กะลา - ปล่อย => Done 796
# 267. แสตมป์ อภิวัชร์ เอื้อถาวรสุข															(stamp) - 1% => Done 1413
# 268. ส้ม มารี เออเจนี เลอเลย์															(zom marie) - หรือฉันคิดไปเอง => Done 1260
# 269. ตั้ง ตะวันวาด วนวิทย์															(tangbadvoice) - เปรตป่ะ => Done 3046
# 270. เคลียร์															(klear) - ถ้าฉันเป็นแม่เธอ => Done 1308
# 271. หนุ่ม กะลา															(num kala) - ลม => Done 786
# 272. เขียนไขและวานิช - หนีห่าง => Done 570
# 273. บอดี้สแลม															(bodyslam) - ความหมาย => Done 828
# 274. โอ โอฬาร ชูใจ															(wanyai) - เงา => Done 1201
# 275. ส้ม มารี เออเจนี เลอเลย์															(zom marie) - กล่องสุ่ม => Done 1278
# 276. แสตมป์ อภิวัชร์ เอื้อถาวรสุข															(stamp) - เข้าฝัน => Done 1486
# 277. ว่าน ธนกฤต พานิชวิทย์ - ยิ่งใกล้ยิ่งไม่รู้จัก => Done 1235
# 278. บอดี้สแลม															(bodyslam) - ผักบุ้งลอยฟ้า => Done 1275
# 279. ลิปตา															(lipta) - อย่าเกลียดกันก็พอ => Done 1290
# 280. บอดี้สแลม															(bodyslam) - ไม่เข้าท่า => Done 999
# 281. โอม รัธพงศ์ ภูรีสิทธิ์															(youngohm) - ไฟเย็น => Done 1715
# 282. หนุ่ม กะลา															(num kala) - อีกนานไหม => Done 907
# 283. ปาล์มมี่															(palmy) - ขวัญเอยขวัญมา => Done 889
# 284. ลาบานูน															(labanoon) - เดลิเวอรี่ => Done 1414
# 285. คอปเตอร์ วิศรุต เล้าเจริญชัย															(copter) - กลับมาทำไม...หา => Done 815
# 286. แวนโก๊ะ															(vangoe) - เก็บทรงไม่อยู่ => Done 2405
# 287. เอิ๊ต ภัทรวี ศรีสันติสุข - ยังไปไม่ไหว => Done 939
# 288. ว่าน ธนกฤต พานิชวิทย์ - คอย เซ็นเตอร์ => Done 1757
# 289. โปเตโต้															(potato) - ทำนองที่มีเธอ => Done 1113
# 290. ส้ม มารี เออเจนี เลอเลย์															(zom marie) - ยิ้มอ่อนและมองบน => Done 1293
# 291. อิ้งค์ วรันธร เปานิล															(ink waruntorn) - อยากเริ่มต้นใหม่กับคนเดิม (repeat) => Done 924
# 292. ลิปตา															(lipta) - เจอแต่คนใจร้าย => Done 1466
# 293. โจอี้ ภูวศิษฐ์ อนันต์พรสิริ															(joey phuwasit) - ดวงเดือน => Done 943
# 294. กวินท์ ดูวาล															(gavin.d) - บวบ => Done 2035
# 295. ทิลลี่เบิร์ด															(tilly birds) - อย่าอยู่เลย => Done 1348
# 296. ลัสส์															(luss) - 247 => Done 1358
# 297. บอย พีซเมกเกอร์															(boy peacemaker) - แลกมาด้วยความโง่ => Done 1223
# 298. ทอม อิศรา กิจนิตย์ชีว์															(tom isara) - ไม่ใช่ไม่รู้สึก => Done 1196
# 299. แจ้ ดนุพล แก้วกาญจน์ - ตายทั้งเป็น => Done 1330
# 300. 2021 ราตรี - จีนี่ จ๋า (2021) => Done 1606
# 301. ส้ม มารี เออเจนี เลอเลย์															(zom marie) - ต้องเสียน้ำตาให้เธออีกกี่ครั้ง => Done 1133
# 302. ซอยแบด															(soybad) - เรื่องเมื่อคืน => Done 2067
# 303. บีน นภสร ชัยพรเรืองเดช															(bean napason) - ไม่อยากเป็นเพื่อนกับแฟนเก่า => Done 1480
# 304. พาวเวอร์ แพท															(power pat) - ต้องคำสาป => Done 1279
# 305. อะตอม ชนกันต์ รัตนอุดม															(atom) - ปล่อยปาก => Done 1217
# 306. ซีเรียส คอปเตอร์															(serious copter) - บอกให้ฟังหน่อยนะ (please tell me) => Done 1123
# 307. ลอสบอย															(lostboy) - ใครคิดถึงก่อนคนนั้นแพ้ => Done 1153
# 308. ทรี แมน ดาวน์ - รถฉันบินไม่ได้ => Done 944
# 309. ค็อกเทล															(cocktail) - ชั่วชีวิต => Done 1321
# 310. อิ้งค์ วรันธร เปานิล															(ink waruntorn) - เผลอหรือตั้งใจ => Done 913
# 311. โปเตโต้															(potato) - หมดความหมาย => Done 1197
# 312. สไปร์ท ศุกลวัฒน์ พวงสมบัติ															(sprite) - ทน => Done 1867
# 313. เอิ๊ต ภัทรวี ศรีสันติสุข - คิดไม่คิด => Done 1017
# 314. ส้ม มารี เออเจนี เลอเลย์															(zom marie) - รู้ได้แล้วมั้ย => Done 1456
# 315. วี วิโอเลต วอเทียร์															(violette wautier) - กักตัว => Done 1123
# 316. คอปเตอร์ วิศรุต เล้าเจริญชัย															(copter) - เดี๋ยวเธอกับเขาก็คืนดีกัน => Done 1630
# 317. หนุ่ม กะลา															(num kala) - จม => Done 1283
# 318. อนาโตมี่ แรบบิต															(anatony rabbit) - ขอให้โลกนี้ใจดีกับเธอ => Done 742

# %%
spotify_with_am[
    (spotify_with_am['language'] == 'TH') 
    & 
    spotify_with_am.lyric.isnull()
].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 929 entries, 0 to 2630
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   track_id         929 non-null    object
#  1   artist           929 non-null    object
#  2   name             929 non-null    object
#  3   cover_image      929 non-null    object
#  4   link             929 non-null    object
#  5   lyric            0 non-null      object
#  6   language         929 non-null    object
#  7   siamzone_artist  831 non-null    object
# dtypes: object(8)
# memory usage: 65.3+ KB

# %%
unique_spotify_song = spotify_with_am.drop_duplicates(['track_id'])
unique_spotify_song[~unique_spotify_song.lyric.isnull()].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 691 entries, 1 to 2623
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   track_id         691 non-null    object
#  1   artist           691 non-null    object
#  2   name             691 non-null    object
#  3   cover_image      691 non-null    object
#  4   link             691 non-null    object
#  5   lyric            691 non-null    object
#  6   language         691 non-null    object
#  7   siamzone_artist  589 non-null    object
# dtypes: object(8)
# memory usage: 48.6+ KB

# %%
spotify_song[(spotify_song.language == 'TH') & spotify_song.lyric.isnull()].head()
# Out:
#                    track_id          artist  \
# id
# 6    4OHu1M6xtQLkgTSao8nYS3        samblack
# 238  7JC59jSvjSbJ2MszeV6fBs          copter
# 359  2K7gwruclvSWntbV21vP6a  earth patravee
# 501  2opZpuOcnBYJbfqm2IJIMU   wan thanakrit
# 989  4SeC84Av9mcpn7TZq3WWpv           pause
#
#                                                 name  \
# id
# 6                                           ไม่ยินดี
# 238  เดี๋ยวเธอกับเขาก็คืนดีกัน Feat. 3rd Tilly Birds
# 359                                        คิดไม่คิด
# 501                            ยิ่งใกล้ยิ่งไม่รู้จัก
# 989      หน้าที่ของความรัก(Mission) Feat. เล็ก พงษธร
#
#                                            cover_image  \
# id
# 6    https://i.scdn.co/image/ab67616d00004851b12d3e...
# 238  https://i.scdn.co/image/ab67616d00004851a232ea...
# 359  https://i.scdn.co/image/ab67616d000048516f60ad...
# 501  https://i.scdn.co/image/ab67616d00004851bd57d8...
# 989  https://i.scdn.co/image/ab67616d00004851ec0f6a...
#
#                                                   link lyric language
# id
# 6    https://open.spotify.com/track/4OHu1M6xtQLkgTS...  None       TH
# 238  https://open.spotify.com/track/7JC59jSvjSbJ2Ms...  None       TH
# 359  https://open.spotify.com/track/2K7gwruclvSWntb...  None       TH
# 501  https://open.spotify.com/track/2opZpuOcnBYJbfq...  None       TH
# 989  https://open.spotify.com/track/4SeC84Av9mcpn7T...  None       TH

# %%
unique_spotify_song[~unique_spotify_song.lyric.isnull()].head()
# Out:
#                   track_id   artist  \
# 1   6VmtHYkk81yli04paFVxqJ    meyou
# 7   4hccrJgNG1BwPa3CWw4NNg  urboytj
# 8   7tFrJ1JPTVmQKVU5XlGQdb     hers
# 9   7JC59jSvjSbJ2MszeV6fBs   copter
# 16  0JK7pZajOQyfJ2OPxkrWbh  pp krit
#
#                                                  name  \
# 1                                     พัทยา (Pattaya)
# 7                                           กอดได้ไหม
# 8                                            ยังคงคอย
# 9     เดี๋ยวเธอกับเขาก็คืนดีกัน Feat. 3rd Tilly Birds
# 16  หลอกกันทั้งนั้น (Fake News) - From "แปลรักฉันด...
#
#                                           cover_image  \
# 1   https://i.scdn.co/image/ab67616d0000485119bf48...
# 7   https://i.scdn.co/image/ab67616d000048518b1d41...
# 8   https://i.scdn.co/image/ab67616d00004851c175e7...
# 9   https://i.scdn.co/image/ab67616d00004851a232ea...
# 16  https://i.scdn.co/image/ab67616d000048510abc19...
#
#                                                  link  \
# 1   https://open.spotify.com/track/6VmtHYkk81yli04...
# 7   https://open.spotify.com/track/4hccrJgNG1BwPa3...
# 8   https://open.spotify.com/track/7tFrJ1JPTVmQKVU...
# 9   https://open.spotify.com/track/7JC59jSvjSbJ2Ms...
# 16  https://open.spotify.com/track/0JK7pZajOQyfJ2O...
#
#                                                 lyric language  \
# 1   hook, ตกหลุมรักสาวพัทยา, ก็เธอช่างสวยเกินจะจิน...       TH
# 7   VERSE, ไม่ได้มาเรียกร้องอะไร, แค่ต้องการมาใช้ค...       TH
# 8   เธอยังคงคิดถึงบ้างไหม, ในวันที่เรานั้นไกลห่าง,...       TH
# 9   เพราะเธอยังคิดถึงเขาทุกวัน, ถึงตัวเธอจะอยู่กับ...       TH
# 16  สายตาที่เธอมองฉัน คำพูดดีๆเหล่านั้น, ที่ทำ เหม...       TH
#
#                                       siamzone_artist
# 1                                มิว ชิษณุชา ตันติเมธ
# 7   ยัวร์บอยทีเจ\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t(urb...
# 8          เฮอร์ส\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t(hers)
# 9                                            คอปเตอร์
# 16  พีพี กฤษฏ์ อำนวยเดชกร\t\t\t\t\t\t\t\t\t\t\t\t\...

# %%
# %run DBConnector.ipynb

# %%
from sqlalchemy.sql import select, update

with engine.connect() as conn:
    for i, t in unique_spotify_song[~unique_spotify_song.lyric.isnull()].iterrows():
        rs = conn.execute(
            select(song_table).\
            where(song_table.c.track_id == t['track_id']).\
            where(song_table.c.lyrics == None)
        )
        
        rows = rs.fetchall()
        if 0 == len(rows):
            continue
        
        for row in rows:
            conn.execute(
                update(song_table).\
                where(song_table.c.track_id == t['track_id']).\
                values(lyrics=t['lyric'])
            )

# %% [markdown]
# ----

# %%
siamzone_with_sc = pd.merge(
    song_cleansing[['track_id', 'artist', 'title', 'mod_title', 'siamzone_id', 'song_id']],
    siamzone_song[['song_id', 'lyric']],
    how='left',
    on=['song_id']
)

# %%
siamzone_with_sc.head()
# Out:
#                  track_id             artist  \
# 0  4tM3ygBuSy0QzB0ihYZQcf  SPRITE, GUYGEEGEE
# 1  19CoWVqDyUbiqxoyMf4HkJ     Anatomy Rabbit
# 2  2ozCc0MSm3ybXugQqfnKOn   Violette Wautier
# 3  7ip4DUtdpLH4TkHfKgFbpf      SERIOUS BACON
# 4  0JK7pZajOQyfJ2OPxkrWbh            PP Krit
#
#                                                title        mod_title  \
# 0                                                 ทน               ทน
# 1                                      Extraordinary    Extraordinary
# 2                                             กักตัว           กักตัว
# 3                               1001 (You're Lovely)             1001
# 4  หลอกกันทั้งนั้น (Fake News) - From "แปลรักฉันด...  หลอกกันทั้งนั้น
#
#    siamzone_id  song_id                                              lyric
# 0      19474.0  19474.0  คงจะเป็นคำถามที่ไม่มีคำตอบ, และอาจจะดูเข้าใจแต...
# 1      18445.0  18445.0  จะเอายังไง ช่วยตอบให้แน่ใจ, เรื่องของเราจะเอาย...
# 2      19658.0  19658.0  หย่างอ้อมบ้าน ชวนหมู่เล่นเกมส์ก่อนน๊า, เลาะเล่...
# 3      19021.0  19021.0  หากเป็นฝันร้าย ตื่นมาก็หาย, ต่อให้จะเป็นยังไงม...
# 4          NaN      NaN                                                NaN

# %%
siamzone_with_sc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 633 entries, 0 to 632
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   song_id    633 non-null    int64
#  1   lyric      633 non-null    object
#  2   track_id   633 non-null    object
#  3   mod_title  633 non-null    object
# dtypes: int64(1), object(3)
# memory usage: 24.7+ KB

# %% [markdown]
# ## Lyric fill

# %%
song_with_lyric = pd.merge(
    spotify_with_am[['track_id', 'artist', 'name', 'cover_image', 'link', 'lyric']],
    siamzone_with_sc[['track_id', 'lyric']],
    how='left',
    on=['track_id']
).drop_duplicates(['track_id'])

# %%
song_with_lyric[['artist', 'name', 'lyric_x', 'lyric_y']].head(20)
# Out:
#              artist                                               name  \
# 0          SAMBLACK                                           ไม่ยินดี
# 1             MEYOU                                    พัทยา (Pattaya)
# 7           UrboyTJ                                          กอดได้ไหม
# 8              Hers                                           ยังคงคอย
# 9            Copter    เดี๋ยวเธอกับเขาก็คืนดีกัน Feat. 3rd Tilly Birds
# 16          PP Krit  หลอกกันทั้งนั้น (Fake News) - From "แปลรักฉันด...
# 18   Earth Patravee                                          คิดไม่คิด
# 22    Wan Thanakrit                              ยิ่งใกล้ยิ่งไม่รู้จัก
# 25            Pause        หน้าที่ของความรัก(Mission) Feat. เล็ก พงษธร
# 26      Ae Jirakorn         เรื่องเดียวที่ถูก - เพลงประกอบละคร ภาตุฆาต
# 28    Ink Waruntorn                               เหงา เหงา (Insomnia)
# 32       TOR Saksit                         ยิ้มก็พอ feat. Wonderframe
# 33      Aof Pongsak                              อยากให้เธอเจอคนแบบเธอ
# 35    Atom Chanakan                                        คุณได้ไปต่อ
# 39   Anatomy Rabbit                              ขอให้โลกนี้ใจดีกับเธอ
# 41    Patrickananda              จันทร์อังคารพุธพฤหัสศุกร์เสาร์อาทิตย์
# 42          PP Krit                        It's Okay Not To Be Alright
# 44       Safeplanet                                              คำตอบ
# 46    SERIOUS BACON                                   มีปัญหาปรึกษาดาว
# 47  Chilling Sunday                                            ดีพอไหม
#
#                                               lyric_x  \
# 0                                                None
# 1   hook, ตกหลุมรักสาวพัทยา, ก็เธอช่างสวยเกินจะจิน...
# 7   VERSE, ไม่ได้มาเรียกร้องอะไร, แค่ต้องการมาใช้ค...
# 8   เธอยังคงคิดถึงบ้างไหม, ในวันที่เรานั้นไกลห่าง,...
# 9                                                None
# 16  สายตาที่เธอมองฉัน คำพูดดีๆเหล่านั้น, ที่ทำ เหม...
# 18                                               None
# 22                                               None
# 25                                               None
# 26                                               None
# 28                                               None
# 32                                               None
# 33                                               None
# 35                                               None
# 39                                               None
# 41                                               None
# 42                                               None
# 44  ฉันเกิดคำถามมากมายในใจ, ไม่อาจจะรู้ความจริงใดใ...
# 46  ไม่รู้เลยว่าเธอ ป่านนี้เป็นอย่างไร, ในวันที่เร...
# 47  เธอก็รู้ ว่าตัวฉันนั้นคิด เธอก็รู้ ว่าตัวฉันนั...
#
#                                               lyric_y
# 0                                                 NaN
# 1                                                 NaN
# 7   ผีสางตนไหนมันดนบันดาล ให้เธอจำแลงลงมา, ทันใดที...
# 8   ลา ลาลัลลาลัล ลา ลา ลาลัลลาลัล ลา, ลา ลาลัลลาล...
# 9                                                 NaN
# 16                                                NaN
# 18  ก็มันไม่ตั้งใจ ผิดไปก็รู้ตัว, ที่แกล้งหนีไปเพร...
# 22  I never let no man, make me feel worthless, Tr...
# 25                                                NaN
# 26                                                NaN
# 28  ไม่หาหรอกเหตุผล ที่คนจะเปลี่ยนผัน, รักเราที่มั...
# 32                                                NaN
# 33  หนาวนี้เธอกอดใคร, หนาวไหมมากอดกัน, ขยับมาข้างฉ...
# 35  ออเจ้าเอย เคยรู้หรือไม่, ตรงนี้ยังมีใคร ฤทัยห่...
# 39                                                NaN
# 41                                                NaN
# 42                                                NaN
# 44  ผ่านไปสองปี ที่เธอมาหายจาก, ข่าวคราวว่า พ่อแม่...
# 46  เมื่อไรที่เธอเหนื่อยล้า, เจ็บปวดหรือเสียน้ำตา,...
# 47  พอได้แล้ว หยุดหลอกตัวเองเสียที, รู้ทั้งรู้ว่าเ...

# %%
song_with_lyric.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 605 entries, 0 to 1641
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   track_id     605 non-null    object
#  1   artist       605 non-null    object
#  2   name         605 non-null    object
#  3   cover_image  605 non-null    object
#  4   link         605 non-null    object
#  5   lyric_x      185 non-null    object
#  6   lyric_y      605 non-null    object
# dtypes: object(7)
# memory usage: 37.8+ KB

# %% [markdown]
# ### Remapping

# %%
song_with_lyric.rename(columns={'lyric_x': 'lyric'}, inplace=True)
song_with_lyric.head()
# Out:
#                  track_id          artist                   name  \
# 0  4hccrJgNG1BwPa3CWw4NNg         UrboyTJ              กอดได้ไหม
# 1  7tFrJ1JPTVmQKVU5XlGQdb            Hers               ยังคงคอย
# 2  2K7gwruclvSWntbV21vP6a  Earth Patravee              คิดไม่คิด
# 6  2opZpuOcnBYJbfqm2IJIMU   Wan Thanakrit  ยิ่งใกล้ยิ่งไม่รู้จัก
# 9  1zX4JRQpUlQSHwccLL6pJN   Ink Waruntorn   เหงา เหงา (Insomnia)
#
#                                          cover_image  \
# 0  https://i.scdn.co/image/ab67616d000048518b1d41...
# 1  https://i.scdn.co/image/ab67616d00004851c175e7...
# 2  https://i.scdn.co/image/ab67616d000048516f60ad...
# 6  https://i.scdn.co/image/ab67616d00004851bd57d8...
# 9  https://i.scdn.co/image/ab67616d00004851e3f31f...
#
#                                                 link  \
# 0  https://open.spotify.com/track/4hccrJgNG1BwPa3...
# 1  https://open.spotify.com/track/7tFrJ1JPTVmQKVU...
# 2  https://open.spotify.com/track/2K7gwruclvSWntb...
# 6  https://open.spotify.com/track/2opZpuOcnBYJbfq...
# 9  https://open.spotify.com/track/1zX4JRQpUlQSHwc...
#
#                                                lyric  \
# 0  VERSE, ไม่ได้มาเรียกร้องอะไร, แค่ต้องการมาใช้ค...
# 1  เธอยังคงคิดถึงบ้างไหม, ในวันที่เรานั้นไกลห่าง,...
# 2                                               None
# 6                                               None
# 9                                               None
#
#                                              lyric_y
# 0  ผีสางตนไหนมันดนบันดาล ให้เธอจำแลงลงมา, ทันใดที...
# 1  ลา ลาลัลลาลัล ลา ลา ลาลัลลาลัล ลา, ลา ลาลัลลาล...
# 2  ก็มันไม่ตั้งใจ ผิดไปก็รู้ตัว, ที่แกล้งหนีไปเพร...
# 6  I never let no man, make me feel worthless, Tr...
# 9  ไม่หาหรอกเหตุผล ที่คนจะเปลี่ยนผัน, รักเราที่มั...

# %%
for i, row in song_with_lyric.iterrows():
    if row['lyric_y'] != None:
        song_with_lyric.loc[i, 'lyric'] = row['lyric_y']

# %%
song_with_lyric.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 633 entries, 0 to 1698
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           633 non-null    int64
#  1   track_id     633 non-null    object
#  2   artist       633 non-null    object
#  3   name         633 non-null    object
#  4   cover_image  633 non-null    object
#  5   link         633 non-null    object
#  6   lyric_x      230 non-null    object
#  7   lyric_y      633 non-null    object
#  8   lyric        633 non-null    object
# dtypes: int64(1), object(8)
# memory usage: 65.6+ KB

# %%
unique_song = song_with_lyric.drop_duplicates(['track_id'])

# %%
unique_song.head()
# Out:
#      id                track_id             artist           name  \
# 0    18  4tM3ygBuSy0QzB0ihYZQcf  SPRITE, GUYGEEGEE             ทน
# 1    21  19CoWVqDyUbiqxoyMf4HkJ     Anatomy Rabbit  Extraordinary
# 3   174  0LLETxISOeZVam4l0RwcpV     Anatomy Rabbit        แอบหวัง
# 5  2953  12DssMinsDjVI4kHF57NL7      Da Endorphine      คืนข้ามปี
# 7    27  2ozCc0MSm3ybXugQqfnKOn   Violette Wautier         กักตัว
#
#                                          cover_image  \
# 0  https://i.scdn.co/image/ab67616d000048511530f7...
# 1  https://i.scdn.co/image/ab67616d00004851bfe7c9...
# 3  https://i.scdn.co/image/ab67616d00004851108d67...
# 5  https://i.scdn.co/image/ab67616d000048513f3739...
# 7  https://i.scdn.co/image/ab67616d00004851816fb6...
#
#                                                 link lyric_x  \
# 0  https://open.spotify.com/track/4tM3ygBuSy0QzB0...    None
# 1  https://open.spotify.com/track/19CoWVqDyUbiqxo...    None
# 3  https://open.spotify.com/track/0LLETxISOeZVam4...    None
# 5  https://open.spotify.com/track/12DssMinsDjVI4k...    None
# 7  https://open.spotify.com/track/2ozCc0MSm3ybXug...    None
#
#                                              lyric_y  \
# 0  คงจะเป็นคำถามที่ไม่มีคำตอบ, และอาจจะดูเข้าใจแต...
# 1  จะเอายังไง ช่วยตอบให้แน่ใจ, เรื่องของเราจะเอาย...
# 3  ไร้ซึ่งตัวตนในสายตาเธอ, ไร้ซึ่งการมองเห็นฉันเส...
# 5  มองเวลาก็เกือบเที่ยงคืน.. สิ้นคืนนี้ ก็เป็นเวล...
# 7  หย่างอ้อมบ้าน ชวนหมู่เล่นเกมส์ก่อนน๊า, เลาะเล่...
#
#                                                lyric
# 0  คงจะเป็นคำถามที่ไม่มีคำตอบ, และอาจจะดูเข้าใจแต...
# 1  จะเอายังไง ช่วยตอบให้แน่ใจ, เรื่องของเราจะเอาย...
# 3  ไร้ซึ่งตัวตนในสายตาเธอ, ไร้ซึ่งการมองเห็นฉันเส...
# 5  มองเวลาก็เกือบเที่ยงคืน.. สิ้นคืนนี้ ก็เป็นเวล...
# 7  หย่างอ้อมบ้าน ชวนหมู่เล่นเกมส์ก่อนน๊า, เลาะเล่...

# %%
unique_song = unique_song[['id', 'track_id', 'artist', 'name', 'cover_image', 'link', 'lyric']]

# %%
unique_song.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 633 entries, 0 to 1698
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           633 non-null    int64
#  1   track_id     633 non-null    object
#  2   artist       633 non-null    object
#  3   name         633 non-null    object
#  4   cover_image  633 non-null    object
#  5   link         633 non-null    object
#  6   lyric        633 non-null    object
# dtypes: int64(1), object(6)
# memory usage: 39.6+ KB

# %%
unique_song.to_csv('export/song_summary.csv')

# %%
# %%capture
# %run ./song-manipulator.ipynb
# Out:
# [{'id': '2', 'track_id': '2bgTY4UwhfBYhGT4HUYStN', 'artist': 'BTS', 'title': 'Butter', 'mod_title': 'Butter', 'link': 'https://open.spotify.com/track/2bgTY4UwhfBYhGT4HUYStN', 'has_lyrics': 'False'}, {'id': '3', 'track_id': '52h8p62Jx8KzQynM6heq7n', 'artist': 'Urworld', 'title': 'Sunkissed', 'mod_title': 'Sunkissed', 'link': 'https://open.spotify.com/track/52h8p62Jx8KzQynM6heq7n', 'has_lyrics': 'False'}, {'id': '8', 'track_id': '4iJyoBOLtHqaGxP12qzhQI', 'artist': 'Justin Bieber', 'title': 'Peaches (feat. Daniel Caesar & Giveon)', 'mod_title': 'Peaches', 'link': 'https://open.spotify.com/track/4iJyoBOLtHqaGxP12qzhQI', 'has_lyrics': 'False'}, {'id': '9', 'track_id': '7MAibcTli4IisCtbHKrGMh', 'artist': 'Bruno Mars, Anderson .Paak, Silk Sonic', 'title': 'Leave The Door Open', 'mod_title': 'Leave The Door Open', 'link': 'https://open.spotify.com/track/7MAibcTli4IisCtbHKrGMh', 'has_lyrics': 'False'}, {'id': '10', 'track_id': '3iPbmpKBMflYd7UjdYftoj', 'artist': 'TWICE', 'title': 'Alcohol-Free', 'mod_title': 'Alcohol', 'link': 'https://open.spotify.com/track/3iPbmpKBMflYd7UjdYftoj', 'has_lyrics': 'False'}, {'id': '11', 'track_id': '2zrhoHlFKxFTRF5aMyxMoQ', 'artist': 'aespa', 'title': 'Next Level', 'mod_title': 'Next Level', 'link': 'https://open.spotify.com/track/2zrhoHlFKxFTRF5aMyxMoQ', 'has_lyrics': 'False'}, {'id': '15', 'track_id': '748mdHapucXQri7IAO8yFK', 'artist': 'Doja Cat', 'title': 'Kiss Me More (feat. SZA)', 'mod_title': 'Kiss Me More', 'link': 'https://open.spotify.com/track/748mdHapucXQri7IAO8yFK', 'has_lyrics': 'False'}, {'id': '16', 'track_id': '6HU7h9RYOaPRFeh0R3UeAr', 'artist': 'Olivia Rodrigo', 'title': 'deja vu', 'mod_title': 'deja vu', 'link': 'https://open.spotify.com/track/6HU7h9RYOaPRFeh0R3UeAr', 'has_lyrics': 'False'}, {'id': '18', 'track_id': '4tM3ygBuSy0QzB0ihYZQcf', 'artist': 'SPRITE, GUYGEEGEE', 'title': 'ทน', 'mod_title': 'ทน', 'link': 'https://open.spotify.com/track/4tM3ygBuSy0QzB0ihYZQcf', 'has_lyrics': 'False'}, {'id': '19', 'track_id': '0AGhwXsWpVOwjHY5yf4dtD', 'artist': 'F.HERO, Txrbo', 'title': 'จำเลยรัก - Defendant Of Love', 'mod_title': 'จำเลยรัก', 'link': 'https://open.spotify.com/track/0AGhwXsWpVOwjHY5yf4dtD', 'has_lyrics': 'False'}, {'id': '20', 'track_id': '4ZtFanR9U6ndgddUvNcjcG', 'artist': 'Olivia Rodrigo', 'title': 'good 4 u', 'mod_title': 'good 4 u', 'link': 'https://open.spotify.com/track/4ZtFanR9U6ndgddUvNcjcG', 'has_lyrics': 'False'}, {'id': '21', 'track_id': '19CoWVqDyUbiqxoyMf4HkJ', 'artist': 'Anatomy Rabbit', 'title': 'Extraordinary', 'mod_title': 'Extraordinary', 'link': 'https://open.spotify.com/track/19CoWVqDyUbiqxoyMf4HkJ', 'has_lyrics': 'False'}, {'id': '22', 'track_id': '5sXuqzLmT1z6Gnf3S2TzSz', 'artist': 'Da Endorphine', 'title': 'สองใจ - เพลงประกอบละคร วันทอง', 'mod_title': 'สองใจ', 'link': 'https://open.spotify.com/track/5sXuqzLmT1z6Gnf3S2TzSz', 'has_lyrics': 'False'}, {'id': '24', 'track_id': '7BoobGhD4x5K96Me0hqC8Q', 'artist': 'Bella Poarch', 'title': 'Build a Bitch', 'mod_title': 'Build a Bitch', 'link': 'https://open.spotify.com/track/7BoobGhD4x5K96Me0hqC8Q', 'has_lyrics': 'False'}, {'id': '27', 'track_id': '2ozCc0MSm3ybXugQqfnKOn', 'artist': 'Violette Wautier', 'title': 'กักตัว', 'mod_title': 'กักตัว', 'link': 'https://open.spotify.com/track/2ozCc0MSm3ybXugQqfnKOn', 'has_lyrics': 'False'}, {'id': '29', 'track_id': '2CVChktEKBsM6v4IfdFU5k', 'artist': 'dhruv', 'title': 'double take', 'mod_title': 'double take', 'link': 'https://open.spotify.com/track/2CVChktEKBsM6v4IfdFU5k', 'has_lyrics': 'False'}, {'id': '31', 'track_id': '7ip4DUtdpLH4TkHfKgFbpf', 'artist': 'SERIOUS BACON', 'title': "1001 (You're Lovely)", 'mod_title': '1001', 'link': 'https://open.spotify.com/track/7ip4DUtdpLH4TkHfKgFbpf', 'has_lyrics': 'False'}, {'id': '33', 'track_id': '5bvgLLWn7IFu6mOa46XaoV', 'artist': 'QLER', 'title': 'จีบ', 'mod_title': 'จีบ', 'link': 'https://open.spotify.com/track/5bvgLLWn7IFu6mOa46XaoV', 'has_lyrics': 'False'}, {'id': '34', 'track_id': '42fR3oINF3KfXCDtheoNiY', 'artist': 'EXO', ' ...
# 2855
# 926
# [{'id': '19456', 'song_id': '20880', 'artist_name': 'ไอเฮดมันเดย์\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t(I Hate Monday)', 'title': 'ยิ่งใกล้ยิ่งเก็บ'}]

# %%
df.head()
# Out:
#    id                track_id             artist  \
# 0  18  4tM3ygBuSy0QzB0ihYZQcf  SPRITE, GUYGEEGEE
# 1  21  19CoWVqDyUbiqxoyMf4HkJ     Anatomy Rabbit
# 2  27  2ozCc0MSm3ybXugQqfnKOn   Violette Wautier
# 3  31  7ip4DUtdpLH4TkHfKgFbpf      SERIOUS BACON
# 4   7  0JK7pZajOQyfJ2OPxkrWbh            PP Krit
#
#                                                title        mod_title  \
# 0                                                 ทน               ทน
# 1                                      Extraordinary    Extraordinary
# 2                                             กักตัว           กักตัว
# 3                               1001 (You're Lovely)             1001
# 4  หลอกกันทั้งนั้น (Fake News) - From "แปลรักฉันด...  หลอกกันทั้งนั้น
#
#                                                 link has_lyrics  found  \
# 0  https://open.spotify.com/track/4tM3ygBuSy0QzB0...      False   True
# 1  https://open.spotify.com/track/19CoWVqDyUbiqxo...      False   True
# 2  https://open.spotify.com/track/2ozCc0MSm3ybXug...      False   True
# 3  https://open.spotify.com/track/7ip4DUtdpLH4TkH...      False   True
# 4  https://open.spotify.com/track/0JK7pZajOQyfJ2O...       True   True
#
#   siamzone_id
# 0       19474
# 1       18445
# 2       19658
# 3       19021
# 4        None

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 712 entries, 0 to 711
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           712 non-null    object
#  1   track_id     712 non-null    object
#  2   artist       712 non-null    object
#  3   title        712 non-null    object
#  4   mod_title    712 non-null    object
#  5   link         712 non-null    object
#  6   has_lyrics   712 non-null    object
#  7   found        712 non-null    bool
#  8   siamzone_id  649 non-null    object
# dtypes: bool(1), object(8)
# memory usage: 45.3+ KB
